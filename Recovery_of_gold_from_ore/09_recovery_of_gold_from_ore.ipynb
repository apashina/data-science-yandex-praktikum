# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-файлов" data-toc-modified-id="Изучение-файлов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изучение файлов</a></span></li><li><span><a href="#Проверка-правильности-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-правильности-расчета-эффективности-обогащения-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Проверка правильности расчета эффективности обогащения</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Изменение-концентрация-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Изменение концентрация металлов (<em>Au</em>, <em>Ag</em>, <em>Pb</em>) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах" data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-и-обучение-модели" data-toc-modified-id="Построение-и-обучение-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Построение и обучение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-для-вычисления-итоговой-метрики-sMAPE" data-toc-modified-id="Функция-для-вычисления-итоговой-метрики-sMAPE-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для вычисления итоговой метрики <em>sMAPE</em></a></span></li><li><span><a href="#Обучение-и-исследование-качества-разных-моделей" data-toc-modified-id="Обучение-и-исследование-качества-разных-моделей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Обучение и исследование качества разных моделей</a></span></li><li><span><a href="#Проверка-модели-на-вменяемость" data-toc-modified-id="Проверка-модели-на-вменяемость-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Проверка модели на вменяемость</a></span></li><li><span><a href="#Проверка-качества-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-качества-модели-на-тестовой-выборке-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проверка качества модели на тестовой выборке</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# ### Описание проекта
#
# Компания «Цифра» разрабатывает решения для эффективной работы промышленных предприятий.
#
# **Цель проекта** – подготовить прототип модели машинного обучения, предсказывающей коэффициент восстановления золота из золотосодержащей руды, для компании «Цифра».
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# В нашем распоряжении сырые данные с параметрами добычи и очистки. Данные находятся в трёх файлах:
#
# * `gold_recovery_train_new.csv` — обучающая выборка,
#
# * `gold_recovery_test_new.csv` — тестовая выборка,
# * `gold_recovery_full_new.csv` — исходные данные.
#
# Данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.
#
# Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.
#
# Исходный датасет содержит обучающую и тестовую выборки со всеми признаками.
#
# **Задачи:**
#
# 1. Подготовить данные:
#     - открыть файлы и изучить их,
#     - проверить, что эффективность обогащения рассчитана правильно; вычислить её на обучающей выборке для признака `rougher.output.recovery`; найти MAE между нашими расчётами и значением признака; описать выводы,
#     - проанализировать признаки, недоступные в тестовой выборке,
#     - провести предобработку данных.
#
#
# 2. Провести исследовательский анализ данных:
#     - посмотреть, как меняется концентрация металлов (*Au*, *Ag*, *Pb*) на различных этапах очистки; описать выводы,
#     - сравнить распределения размеров гранул сырья на обучающей и тестовой выборках; если распределения сильно отличаются друг от друга, оценка модели будет неправильной,
#     - исследовать суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
#
# 3. Построить и обучить модель:
#     - написать функцию для вычисления итоговой *sMAPE*,
#     - обучить разные модели и оценить их качество кросс-валидацией; выбрать лучшую модель и проверить её на тестовой выборке; описать выводы.
#
# **Описание данных**
#
# **Технологический процесс**
#
# * *Rougher feed* — исходное сырье,
# * *Rougher additions* (или *reagent additions*) — флотационные реагенты: Xanthate, Sulphate, Depressant:
#     * *Xanthate* — ксантогенат (промотер, или активатор флотации),
#     * *Sulphate* — сульфат (на данном производстве сульфид натрия),
#     * *Depressant* — депрессант (силикат натрия),
# * *Rougher process* (англ. «грубый процесс») — флотация,
# * *Rougher tails* — отвальные хвосты,
# * *Float banks* — флотационная установка,
# * *Cleaner process* — очистка,
# * *Rougher Au* — черновой концентрат золота,
# * *Final Au* — финальный концентрат золота.
#
# **Параметры этапов**
#
# * *air amount* — объём воздуха,
# * *fluid levels* — уровень жидкости,
# * *feed size* — размер гранул сырья,
# * *feed rate* — скорость подачи.
#
#
# **Наименование признаков**
#
# `[этап].[тип_параметра].[название_параметра]`
#
# Возможные значения для блока `[этап]`:
#
# * *rougher* — флотация,
# * *primary_cleaner* — первичная очистка,
# * *secondary_cleaner* — вторичная очистка,
# * *final* — финальные характеристики.
#
# Возможные значения для блока `[тип_параметра]`:
#
# * *input* — параметры сырья,
# * *output* — параметры продукта,
# * *state* — параметры, характеризующие текущее состояние этапа,
# * *calculation* — расчётные характеристики.

# %% [markdown]
# ### Подготовка данных

# %%
# импортирование необходимых библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.dummy import DummyRegressor

# %%
# %matplotlib inline
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format

# %%
# загрузка данных
file_path = 'E:/ЯП/Курс_спец_Data_Science/9_Сборный_проект_2/'

try:
    df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date', parse_dates=True)
    df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date', parse_dates=True)
    df_full = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date', parse_dates=True)
except:
    df_train = pd.read_csv(file_path + 'gold_recovery_train_new.csv', index_col='date', parse_dates=True)
    df_test = pd.read_csv(file_path + 'gold_recovery_test_new.csv', index_col='date', parse_dates=True)
    df_full = pd.read_csv(file_path + 'gold_recovery_full_new.csv', index_col='date', parse_dates=True)

# %% [markdown]
# #### Изучение файлов

# %%
def analyze_df(df):
    """
    Функция получает на вход датасет. 
    Выводит на экран первые 3 строки датафрейма, все его атрибуты,
    количество и процент пропущенных значений для каждого столбца.
    
    """
    print('\033[1m'+'Первые 3 строки датафрейма'+'\033[0m')
    display(df.head(3))
    print('\n'+'\033[1m'+'Запрос всех атрибутов датафрейма'+'\033[0m'+'\n')
    df.info()
    print('\n'+'\033[1m'+'Количество и процент пропущенных значений для каждого столбца'+'\033[0m')
    display(df.isna().agg(['sum', lambda x: sum(x) / df_train.shape[0] * 100]).T.style.format("{:,.2f}"))

# %% [markdown]
# **Обучающая выборка**

# %%
analyze_df(df_train)
# Out:
# Первые 3 строки датафрейма
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                         6.06                         9.89
# 2016-01-15 01:00:00                         6.03                         9.97
# 2016-01-15 02:00:00                         6.06                        10.21
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                          5.51
# 2016-01-15 01:00:00                          5.26
# 2016-01-15 02:00:00                          5.38
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                        42.19                  70.54
# 2016-01-15 01:00:00                        42.70                  69.27
# 2016-01-15 02:00:00                        42.66                  68.12
#
#                      final.output.tail_ag  final.output.tail_pb  \
# date
# ...

# %% [markdown]
# Обучающая выборка состоит из 14149 строк и 86 столбцов. Имеются пропущенные значения. Типы переменных в колонках соответствуют описанию данных.

# %% [markdown]
# **Тестовая выборка**

# %%
analyze_df(df_test)
# Out:
# Первые 3 строки датафрейма
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                         210.80
# 2016-09-01 01:59:59                         215.39
# 2016-09-01 02:59:59                         215.26
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                             14.99
# 2016-09-01 01:59:59                             14.99
# 2016-09-01 02:59:59                             12.88
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                             8.08
# 2016-09-01 01:59:59                             8.08
# 2016-09-01 02:59:59                             7.79
#
#                      primary_cleaner.input.xanthate  \
# date
# 2016-09-01 00:59:59                            1.01
# 2016-09-01 01:59:59                            0.99
# 2016-09-01 02:59:59                            1.00
#
# ...

# %% [markdown]
# Тестовая выборка состоит из 5290 строк и 52 столбцов. В некоторых колонках имеются пропущенные значения. Типы переменных в столбцах соответствуют описанию данных.

# %% [markdown]
# **Исходные данные**

# %%
analyze_df(df_full)
# Out:
# Первые 3 строки датафрейма
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                         6.06                         9.89
# 2016-01-15 01:00:00                         6.03                         9.97
# 2016-01-15 02:00:00                         6.06                        10.21
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                          5.51
# 2016-01-15 01:00:00                          5.26
# 2016-01-15 02:00:00                          5.38
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                        42.19                  70.54
# 2016-01-15 01:00:00                        42.70                  69.27
# 2016-01-15 02:00:00                        42.66                  68.12
#
#                      final.output.tail_ag  final.output.tail_pb  \
# date
# ...

# %% [markdown]
# Исходные данные состоят из 19439 (14149 + 5290) строк и 86 столбцов. В некоторых колонках имеются пропущенные значения. В целевых признаках `rougher.output.recovery` и `final.output.recovery` пропуски отсутствуют. Типы переменных в столбцах соответствуют описанию данных.

# %% [markdown]
# #### Проверка правильности расчета эффективности обогащения
#
# Эффективность обогащения рассчитывается по формуле:
#
# $$Recovery = \frac{C(F-T)}{F(C-T)}*100\%,$$
#
# где:
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.
#
# Вычислим эффективность обогащения чернового концентрата `rougher.output.recovery` на обучающей выборке. Найдем *MAE* между нашими расчётами и значением признака.

# %%
C = df_train['rougher.output.concentrate_au']
F = df_train['rougher.input.feed_au']
T = df_train['rougher.output.tail_au']

# %%
recovery = 100 * C * (F - T) / (F * (C - T))

# %%
mae_recovery = mean_absolute_error(recovery.dropna(), df_train["rougher.output.recovery"])
print(f'MAE между нашими расчётами и значением признака: {mae_recovery:.2e} %.')
# Out:
# MAE между нашими расчётами и значением признака: 1.15e-14 %.

# %% [markdown]
# #### Анализ признаков, недоступных в тестовой выборке
#
# Найдем признаки, которые есть в обучающей выборке, но которых нет в тестовой.

# %%
set(df_train.columns) - set(df_test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Мы видим, что в тестовую выборку не входят все параметры типа `output` (параметры продукта) и `calculation` (расчётные характеристики). Эти признаки недоступны, поскольку их невозможно получить или измерить во время выполнения технологического процесса.

# %% [markdown]
# #### Предобработка данных
#
# Из исходных данных добавим два целевых признака `rougher.output.recovery` и `final.output.recovery` в тестовую выборку.

# %%
# размер тестовой выборки
df_test.shape
# Out:
# (5290, 52)

# %%
# добавление целевых признаков в тестовую выборку
df_test = df_test.merge(df_full[['rougher.output.recovery', 'final.output.recovery']], left_index=True, right_index=True)

# %%
# размер тестовой выборки
df_test.shape
# Out:
# (5290, 54)

# %% [markdown]
# **Заполнение пропусков**
#
# Заполнять пропуски будем, исходя из того, что соседние по времени параметры часто похожи.

# %%
# количество пропусков в обучающей выборке
df_train.isna().sum().sum()
# Out:
# 4100

# %%
# заполнение пропусков значением из последующей строки
df_train.ffill(axis=0, inplace=True)

# %%
# количество пропусков в обучающей выборке
df_train.isna().sum().sum()
# Out:
# 0

# %%
# количество пропусков в тестовой выборке
df_test.isna().sum().sum()
# Out:
# 90

# %%
# заполнение пропусков значением из последующей строки
df_test.ffill(axis=0, inplace=True)

# %%
# количество пропусков в тестовой выборке
df_test.isna().sum().sum()
# Out:
# 0

# %%
# количество пропусков в исходных данных
df_full.isna().sum().sum()
# Out:
# 4481

# %%
# заполнение пропусков значением из последующей строки
df_full.ffill(axis=0, inplace=True)

# %%
# количество пропусков в исходных данных
df_full.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# #### Вывод
#
# В этой части проекта:
#
# * проведено ознакомление с исходными данными,
# * подтверждена правильность расчета эффективности обогащения,
# * проанализированы признаки, недоступные в тестовой выборке - это все параметры типа output (параметры продукта) и calculation (расчётные характеристики),
# * в тестовую выборку из исходных данных добавлены два целевых признака,
# * в целевых признаках пропусков не обнаружено,
# * пропуски в других колонках были заполнены на основании похожести соседних по времени параметров.

# %% [markdown]
# ###  Исследовательский анализ данных
#
# #### Изменение концентрация металлов (*Au*, *Ag*, *Pb*) на различных этапах очистки

# %%
# список названий металлов
metals = ['au', 'ag', 'pb']

# список параметров концентраций на различных этапах очистки
concentrations = [
    'rougher.input.feed',
    'rougher.output.concentrate',
    'primary_cleaner.output.concentrate',
    'final.output.concentrate',
]

# построение графиков изменения концентрации различных металлов на разных стадиях очистки
for metal in metals:
    # список названий столбцов с концентрациями металла на различных этапах очистки
    concentration_columns = [x + '_' + metal for x in concentrations]
    df_full[concentration_columns] \
    .plot(
            kind='hist',
            figsize=(15,5),
            bins=150,
            alpha=0.5
    )
    plt.xlabel('Концентрация', fontsize=12)
    plt.ylabel('Частота', fontsize=12)
    plt.title(f'Гистограммы концентрации металла {metal.title()} на различных этапах очистки\n', fontsize=14)
    plt.legend(loc='upper right')

# %%
# создание датафрейма со средними значениями концентрации металлов на различных этапах очистки
mean_concentrations_metals = pd.DataFrame(columns=metals, index=concentrations)

# %%
for metal in metals:
    for concentration in concentrations:
        mean_concentrations_metals.loc[concentration, metal] = df_full[concentration + '_' + metal].mean()

# %%
mean_concentrations_metals
# Out:
#                                       au    ag   pb
# rougher.input.feed                  8.27  8.79 3.59
# rougher.output.concentrate         19.77 11.99 7.61
# primary_cleaner.output.concentrate 32.12  8.44 9.81
# final.output.concentrate           44.08  5.17 9.98

# %%
# построение графиков средней концентрации различных металлов на разных стадиях очистки
for metal in metals:
    mean_concentrations_metals[metal]\
    .plot(
        grid=True,
        figsize=(15,5),
        legend=True
        )
    plt.xlabel('Стадии очистки', fontsize=12)
    plt.ylabel('Концентрация', fontsize=12)
    plt.title(f'Средние значения концентрации металлов Au, Ag и Pb на различных этапах очистки\n', fontsize=14)

# %% [markdown]
# Из рисунков и таблицы выше замечаем, что:
#
# * с каждой стадией концентрация золота (*Au*) увеличивается, финальная концентрация больше изначальной примерно в 5.3 раза,
# * концентрация серебра (*Ag*) после этапа флотации начинает снижаться - в 2.3 раза,
# * концентрация свинца (*Pb*) незначительно возрастает на протяжении всех этапов обработки, общее увеличение - в 2.8 раза,
# * имеются объекты с нулевой концентрацией металлов.

# %% [markdown]
# #### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках
#
# Если распределения размеров гранул сырья на обучающей и тестовой выборках сильно отличаются друг от друга, оценка модели будет неправильной. Проверим это.

# %%
plt.figure(figsize=(15,5))
sns.kdeplot(data=df_train['rougher.input.feed_size'], label='train')
sns.kdeplot(data=df_test['rougher.input.feed_size'], label='test')
plt.grid()
plt.ylabel('Плотность', fontsize=12)
plt.xlabel('Размеры гранул сырья', fontsize=12)
plt.title('Распределения размеров гранул сырья на обучающей и тестовой выборках\n', fontsize=14)
plt.xlim(0, 200)
plt.legend(loc='upper right');

# %% [markdown]
# Визуально значительных отличий в распределениях нет, значит, оценка модели будет правильной.

# %% [markdown]
# #### Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах

# %%
# добавление столбцов с суммарными концентрациями всех веществ на разных стадиях
for concentration in concentrations:
    df_train[concentration] = 0
    for substance in metals + ['sol']:
        df_train[concentration] += df_train[concentration + '_' + substance]

# %%
df_train[concentrations].head(3)
# Out:
#                      rougher.input.feed  rougher.output.concentrate  \
# date
# 2016-01-15 00:00:00               51.68                       66.42
# 2016-01-15 01:00:00               50.66                       67.01
# 2016-01-15 02:00:00               50.61                       66.10
#
#                      primary_cleaner.output.concentrate  \
# date
# 2016-01-15 00:00:00                               72.64
# 2016-01-15 01:00:00                               72.54
# 2016-01-15 02:00:00                               72.10
#
#                      final.output.concentrate
# date
# 2016-01-15 00:00:00                     63.64
# 2016-01-15 01:00:00                     63.96
# 2016-01-15 02:00:00                     64.31

# %%
# построение гистограмм суммарных концентраций всех веществ на разных стадиях очистки
for concentration in concentrations:
    df_train[concentration] \
    .plot(
    kind='hist',
    figsize=(15,4),
    bins=150,
    grid=True)
    plt.xlabel('Суммарная концентрация', fontsize=12)
    plt.ylabel('Частота', fontsize=12)
    plt.title(f'Гистограмма суммарной концентрации всех веществ на стадии {concentration}\n', fontsize=14)
    plt.xlim(-1, 90)
    plt.show()

# %% [markdown]
# Дисперсия суммарной концентрации всех веществ на протяжении стадий очистки уменьшается, среднее значение концентрации всех веществ в финальном концентрате больше чем в сырье.
#
# Наблюдаем выбросы в виде нулевых значений суммарной концентрации веществ, что может быть вызвано ошибками измерительного обородувания.
#
# На каждом этапе оставим объекты, у которых суммарная концентрация веществ больше 10. Будем контролировать количество удаленных записей.

# %%
def lost_observations(df):
    """
    Функция получает на вход обработанный датасет. 
    Выводит на экран процент удаленных записей из исходного датасета.
    
    """    
    print(f'{(14149 - df.shape[0]) / 14149:.2%}')

# %%
df_train = df_train[df_train["rougher.input.feed"] > 10]

# %%
lost_observations(df_train)
# Out:
# 0.07%

# %%
df_train = df_train[df_train["rougher.output.concentrate"] > 10]

# %%
lost_observations(df_train)
# Out:
# 2.17%

# %%
df_train = df_train[df_train["primary_cleaner.output.concentrate"] > 10]

# %%
lost_observations(df_train)
# Out:
# 3.70%

# %%
df_train = df_train[df_train["final.output.concentrate"] > 10]

# %%
lost_observations(df_train)
# Out:
# 4.09%

# %% [markdown]
# Таким образом, из обучающей выборки удалили 4.09 % объектов с аномальными значениями концентраций веществ.

# %% [markdown]
# #### Вывод
#
# В ходе исследовательского анализа данных обнаружено:
#
# * на протяжении всех этапов очистки концентрация золота растет и в конце становится в 5.3 раза больше чем в начале,
# * концентрация серебра после этапа флотации начинает снижаться - в 2.3 раза,
# * концентрация свинца медленно растет в течение всех этапов очистки - в 2.8 раза,
# * распределения размеров гранул сырья на обучающей и тестовой выборках визуально отличаются незначительно, поэтому оценка модели будет правильной,
# * разброс суммарной концентрации всех веществ по мере прохождения стадий очистки снижается, и среднее значение концентрации веществ в финальном концентрате больше чем в сырье,
# * имеются выбросы в виде нулевых значений суммарной концентрации веществ, эти аномальные значения были удалены из обучающей выборки, потеря данных составила 4.09 %.

# %% [markdown]
# ### Построение и обучение модели
#
# В обучающей выборке оставим только те признаки, которые присутствуют в тестовой.

# %%
df_train = df_train[df_test.columns]

# %%
df_train.shape
# Out:
# (13570, 54)

# %%
df_test.shape
# Out:
# (5290, 54)

# %%
(df_train.columns == df_test.columns).sum()
# Out:
# 54

# %% [markdown]
# #### Функция для вычисления итоговой метрики *sMAPE*
#
# Напишем функции для вычисления метрик качества *sMAPE*.

# %%
def smape(y_true, y_pred):
    """
    Функция получает на вход значения целевого признака и предсказание модели. 
    Возвращает метрику качества sMAPE.
    
    """
    y_true = y_true.to_numpy()
    return np.mean(np.abs(y_true - y_pred) / ((np.abs(y_true) + np.abs(y_pred)) / 2)) * 100


def total_smape(rougher_smape, final_smape):
    """
    Функция получает на вход значения метрик sMAPE, оценивающих качество предсказания 
    эффективности обогащения чернового концентрата и финального концентрата соответственно. 
    Возвращает итоговую sMAPE.
    
    """
    return 0.25 * rougher_smape + 0.75 * final_smape

# %% [markdown]
# #### Обучение и исследование качества разных моделей
#
# Сформируем обучающие и тестовые выборки для предсказания эффективности обогащения чернового и финального концентратов.

# %%
def train_test_rougher(data_train, data_test):
    """
    Функция получает на вход обучающую и тестовую выборки. 
    Выделяет признаки, которые являются значимыми для предсказания эффективности обогащения 
    чернового концентрата, и сам целевой признак.
    Возвращает кортеж с признаками из обучающей и тестовой выборок, целевыми признаками из 
    обучающей и тестовой выборок.
    
    """    
    
    columns = data_train.columns.to_list()
    columns_rougher = [x for x in columns if ('rougher.input' in x) or ('rougher.state' in x)]
    X_train = data_train[columns_rougher]
    X_test = data_test[columns_rougher]
    y_train = data_train['rougher.output.recovery']
    y_test = data_test['rougher.output.recovery']
    
    return X_train, X_test, y_train, y_test



def train_test_final(data_train, data_test):
    """
    Функция получает на вход обучающую и тестовую выборки. 
    Выделяет признаки, которые являются значимыми для предсказания эффективности обогащения 
    финального концентрата, и сам целевой признак.
    Возвращает кортеж с признаками из обучающей и тестовой выборок, целевыми признаками из 
    обучающей и тестовой выборок.
    
    """     
    X_train = data_train.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
    X_test = data_test.drop(['rougher.output.recovery', 'final.output.recovery'], axis=1)
    y_train = data_train['final.output.recovery']
    y_test = data_test['final.output.recovery']
    
    return X_train, X_test, y_train, y_test

# %%
X_train_rougher, X_test_rougher, y_train_rougher, y_test_rougher = train_test_rougher(df_train, df_test)

# %%
X_train_final, X_test_final, y_train_final, y_test_final = train_test_final(df_train, df_test)

# %% [markdown]
# Мы решаем задачу регресси, в качестве моделей обучения будем использовать линейную регрессию, дерево решений и случайный лес. Выбор модели наилучшего качества будем осуществлять с помощью pipeline и RandomizedSearchCV.

# %%
# создание pipeline
pipeline = Pipeline([('scaler', StandardScaler()),
                     ('regressor', LinearRegression())])

# %%
# создание сетки гиперпараметров
params = [{
        'regressor': [LinearRegression()]
    },
        
    {
        'regressor': [RandomForestRegressor(random_state=12345)],
        'regressor__n_estimators': range(40, 171, 20),
        'regressor__max_depth': range(3, 26),
        'regressor__min_samples_split': range(2, 203, 40),
        'regressor__min_samples_leaf': range(1, 202, 40),
        'scaler': [None]
    },
    
    {
        'regressor': [DecisionTreeRegressor(random_state=12345)],
        'regressor__max_depth': range(3, 26),
        'regressor__min_samples_split': range(2, 203, 40),
        'regressor__min_samples_leaf': range(1, 202, 40),
        'scaler': [None]
    }

]

# %% [markdown]
# Оценщиком качества модели будет пользовательская функция smape, значение которой должно быть низким.

# %%
my_scoring = make_scorer(smape, greater_is_better=False)

# %%
# создание объекта RandomizedSearchCV для предсказания 'rougher.output.recovery'
grid_rougher = RandomizedSearchCV(pipeline,
                    params,
                    n_iter=30,
                    cv=5,
                    verbose=1,
                    random_state=12345,
                    scoring=my_scoring,
                    n_jobs=-1)

# %%
# %%time
# запуск поиска по сетке для предсказания 'rougher.output.recovery'
grid_rougher.fit(X_train_rougher, y_train_rougher)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# CPU times: total: 6.75 s
# Wall time: 2min 26s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('regressor',
#                                               LinearRegression())]),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions=[{'regressor': [LinearRegression()]},
#                                         {'regressor': [RandomForestRegressor(max_depth=17,
#                                                                              min_samples_split=162,
#                                                                              n_estimators=40,
#                                                                              random_state=12345)],
#                                          'regressor__max_depth': range(3, 26),
# ...

# %%
# наилучшая модель, предсказывающая 'rougher.output.recovery', согласно метрике sMAPE
grid_rougher.best_estimator_
# Out:
# Pipeline(steps=[('scaler', None),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=17, min_samples_split=162,
#                                        n_estimators=40, random_state=12345))])

# %%
# наилучшее значение метрики sMAPE для модели, предсказывающей 'rougher.output.recovery'
smape_rougher = np.abs(grid_rougher.best_score_)
print(f'Наилучшее значение метрики sMAPE для модели, предсказывающей \'rougher.output.recovery\':{smape_rougher: .2f} %.')
# Out:
# Наилучшее значение метрики sMAPE для модели, предсказывающей 'rougher.output.recovery': 6.31 %.

# %%
# создание объекта RandomizedSearchCV для предсказания 'final.output.recovery'
grid_final = RandomizedSearchCV(
                    pipeline,
                    params,
                    n_iter=30,
                    cv=5,
                    verbose=1,
                    random_state=12345,
                    scoring=my_scoring,
                    n_jobs=-1)

# %%
# %%time
# запуск поиска по сетке для предсказания 'final.output.recovery'
grid_final.fit(X_train_final, y_train_final)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# CPU times: total: 42.1 s
# Wall time: 6min 42s
# RandomizedSearchCV(cv=5,
#                    estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                              ('regressor',
#                                               LinearRegression())]),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions=[{'regressor': [LinearRegression()]},
#                                         {'regressor': [RandomForestRegressor(max_depth=11,
#                                                                              min_samples_leaf=121,
#                                                                              min_samples_split=162,
#                                                                              n_estimators=160,
#                                                                              random_state=12345)],
# ...

# %%
# наилучшая модель, предсказывающая 'final.output.recovery', согласно метрике sMAPE
grid_final.best_estimator_
# Out:
# Pipeline(steps=[('scaler', None),
#                 ('regressor',
#                  RandomForestRegressor(max_depth=11, min_samples_leaf=121,
#                                        min_samples_split=162, n_estimators=160,
#                                        random_state=12345))])

# %%
# наилучшее значение метрики sMAPE для модели, предсказывающей 'final.output.recovery'
smape_final = np.abs(grid_final.best_score_)
print(f'Наилучшее значение метрики sMAPE для модели, предсказывающей \'final.output.recovery\':{smape_final: .2f} %.')
# Out:
# Наилучшее значение метрики sMAPE для модели, предсказывающей 'final.output.recovery': 8.81 %.

# %%
print(f'Наилучшее значение итоговой sMAPE:{total_smape(smape_rougher, smape_final): .2f} %.')
# Out:
# Наилучшее значение итоговой sMAPE: 8.18 %.

# %% [markdown]
# Таким образом, лучшими оказались модели случайного леса:
#
# * гипрепараметры модели, предсказывающей эффективность обогащения чернового концентрата - `max_depth=17`, `min_samples_split=162`, `n_estimators=40`,
#
# * гипрепараметры модели, предсказывающей эффективность обогащения финального концентрата - `max_depth=11`, `min_samples_leaf=121`, `min_samples_split=162`, `n_estimators=160`.

# %% [markdown]
# #### Проверка модели на вменяемость
#
# Для проверки модели на адекватность будем использовать константную модель `DummyRegressor()`, которая всегда предсказывает медианное значение целевого признака обучающей выборки.

# %%
# получение структуры данных для регрессора DummyRegressor
model_dummy_rougher = DummyRegressor(strategy='median')
model_dummy_final = DummyRegressor(strategy='median')

# обучение модели, предсказывающей 'rougher.output.recovery'
model_dummy_rougher.fit(X_train_rougher, y_train_rougher)
# обучение модели, предсказывающей 'final.output.recovery'
model_dummy_final.fit(X_train_final, y_train_final)
# Out:
# DummyRegressor(strategy='median')

# %%
smape_dummy_rougher = smape(y_test_rougher, model_dummy_rougher.predict(X_test_rougher))
print(f'Значение sMAPE для константной модели, предсказывающей \'rougher.output.recovery\' на тестовой выборке:{smape_dummy_rougher: .2f} %.')
# Out:
# Значение sMAPE для константной модели, предсказывающей 'rougher.output.recovery' на тестовой выборке: 8.53 %.

# %%
smape_dummy_final = smape(y_test_final, model_dummy_final.predict(X_test_final))
print(f'Значение sMAPE для константной модели, предсказывающей \'final.output.recovery\' на тестовой выборке:{smape_dummy_final: .2f} %.')
# Out:
# Значение sMAPE для константной модели, предсказывающей 'final.output.recovery' на тестовой выборке: 9.76 %.

# %%
print(f'Итоговая sMAPE для константной модели на тестовой выборке:{total_smape(smape_dummy_rougher, smape_dummy_final): .2f} %.')
# Out:
# Итоговая sMAPE для константной модели на тестовой выборке: 9.45 %.

# %% [markdown]
# Значение итоговой sMAPE константной модели (9.45 %) больше, чем выбранной нами (8.18 %). Проверка пройдена.

# %% [markdown]
# #### Проверка качества модели на тестовой выборке

# %%
smape_test_rougher = smape(y_test_rougher, grid_rougher.predict(X_test_rougher))
print(f'Значение sMAPE для модели, предсказывающей \'rougher.output.recovery\' на тестовой выборке:{smape_test_rougher: .2f} %.')
# Out:
# Значение sMAPE для модели, предсказывающей 'rougher.output.recovery' на тестовой выборке: 8.36 %.

# %%
smape_test_final = smape(y_test_final, grid_final.predict(X_test_final))
print(f'Значение sMAPE для модели, предсказывающей \'final.output.recovery\' на тестовой выборке:{smape_test_final: .2f} %.')
# Out:
# Значение sMAPE для модели, предсказывающей 'final.output.recovery' на тестовой выборке: 9.57 %.

# %%
print(f'Значение итоговой sMAPE на тестовой выборке:{total_smape(smape_test_rougher, smape_test_final): .2f} %.')
# Out:
# Значение итоговой sMAPE на тестовой выборке: 9.27 %.

# %% [markdown]
# #### Вывод
#
# На этом этапе работы:
#
# * написаны функции для вычисления итоговой *sMAPE*, по значению которой оценивалось качество моделей,
# * обучены модели линейной регресси, дерева решений и случайного леса, выбраны модели с наилучшим значением метрики качества *sMAPE* с помощью рандомизированного поиска по гиперпараметрам, ими оказались модели случайного леса с итоговым *sMAPE* 8.18 %,
# * проверена адекватность построенных моделей, итоговый *sMAPE* константной модели составил 9.45 %,
# * итоговый *sMAPE* построенных моделей случайного леса на тестовой выборке равен 9.27 %.

# %% [markdown]
# ### Общий вывод
#
# Было проведено исследование, позволившее смоделировать процесс восстановления золота из золотосодержащей руды. Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками. Входные данные – сырые данные с параметрами добычи и очистки, предоставленные компанией "Цифра".
#
# Изучение файлов с данными и исследовательский анализ данных показали необходимость предобработки. Пропущенные значения и аномалии были заполнены и устранены соответственно.
#
# Требовалось спрогнозировать сразу две величины: эффективность обогащения чернового концентрата `rougher.output.recovery` и
# эффективность обогащения финального концентрата `final.output.recovery`. С этой целью были построены и обучены несколько моделей с помощью рандомизированного поиска по гиперпараметрам (`RandomizedSearchCV`). В результате наилучшими оказалась модели регресси, обученные алгоритмом случайного леса, с **итоговой метрикой *sMAPE* 8.18 %**:
#
# * гипрепараметры модели, предсказывающей `rougher.output.recovery` - `max_depth=17`, `min_samples_split=162`, `n_estimators=40`,
#
# * гипрепараметры модели, предсказывающей `final.output.recovery` - `max_depth=11`, `min_samples_leaf=121`, `min_samples_split=162`, `n_estimators=160`.
#
# Адекватность построенных моделей подтвердилась путем сравнения с работой константной модели `DummyRegressor`, **итоговая *sMAPE***  которой составила **9.45 %**.
#
# Окончательная проверка качества моделей на тестовой выборке показала значение **итоговой *sMAPE* 9.27 %**.
